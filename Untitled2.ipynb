# %% [markdown]
# <a href="https://colab.research.google.com/github/meduardafigueiredo/Cartorioebac/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1º Exercício: Olá, mundo**

# %%
print("olá,mundo")
# Out:
# olá,mundo

# %% [markdown]
# ![maria.eduarda.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **2º Exercício: Números**

# %% [markdown]
# **Ticket médio diário do dia 19/01**

# %%
svv_19 = 153.98
sqv_19 = 3

tkt_19 = svv_19 / sqv_19
print(tkt_19)
# Out:
# 51.32666666666666

# %% [markdown]
# **Ticket médio diário do dia 20/01**

# %%
svv_20 = 337.01
sqv_20 = 7

tkt_20 = svv_20 / sqv_20
print(tkt_20)
# Out:
# 48.144285714285715

# %% [markdown]
# **Ticket médio diário do dia 23/01**

# %%
svv_23 = 295.33
sqv_23 = 5

tkt_23 = svv_23 / sqv_23
print(tkt_23)
# Out:
# 59.065999999999995

# %% [markdown]
# **Ticket médio**

# %%
tkt = (tkt_19 + tkt_20 + tkt_23) / 3
print(tkt)
# Out:
# 52.8456507936508

# %% [markdown]
# # **3º Exercício: String**

# %%
txt = "hello, and welcome to my world."

x = txt.capitalize()

print (x)
# Out:
# Hello, and welcome to my world.

# %%
txt = "apple, banana, cherry"

x = txt.lower()

print(x)
# Out:
# apple, banana, cherry

# %%
txt = "Hello my FRIENDS"

x = txt.lower()

print(x)
# Out:
# hello my friends

# %% [markdown]
# # **4º Exercício: Booleanos**

# %%
print(True | True)
print(True | False)
print(False | False)
print(False | True)
# Out:
# True
# True
# False
# True

# %%
codigo_de_seguranca = "161"
codigo_de_seguranca_cadastro = "015"

pode_efetuar_pagamento = codigo_de_seguranca == codigo_de_seguranca_cadastro
print(pode_efetuar_pagamento)
# Out:
# False
